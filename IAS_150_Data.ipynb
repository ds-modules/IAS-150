# %% [markdown]
# # IAS 150 Data

# %% [markdown]
# Note: See the python file for 'migrant_functions.py' for functions and their documentation

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import migrant_functions as mf

# %% [markdown]
# ### Data Cleaning

# %%
male_migrants = mf.load_data_excel('male_migrant_info.xlsx')

# %%
male_migrants.head()
# Out:
#     Year     Code   Country    Total  Afghanistan  Albania  Algeria  \
# 13  1990  1990014   Burundi   333110            0        0        0
# 14  1990  1990015   Comoros    14079            0        0        0
# 15  1990  1990016  Djibouti   122221            0        0        0
# 16  1990  1990017   Eritrea    11848            0        0        0
# 17  1990  1990018  Ethiopia  1155390            0        0        0
#
#     American Samoa  Andorra  Angola    ...     Uruguay  Uzbekistan  Vanuatu  \
# 13               0        0       0    ...           0           0        0
# 14               0        0       0    ...           0           0        0
# 15               0        0       0    ...           0           0        0
# 16               0        0     247    ...           0           0        0
# 17               0        0       0    ...           0           0        0
#
#     Venezuela (Bolivarian Republic of)  Viet Nam  Wallis and Futuna Islands  \
# 13                                   0         0                          0
# 14                                   0         0                          0
# 15                                   0         0                          0
# 16                                   0         0                          0
# 17                                   0         0                          0
#
#     Western Sahara  Yemen  Zambia  Zimbabwe
# 13               0      0       0         0
# 14               0      0       0         0
# 15               0    289       0         0
# 16               0      0      91        82
# 17               0     68       0         0
#
# [5 rows x 236 columns]

# %%
Central_America = ['Cuba', 'El Salvador', 'Guatemala', 'Honduras', 'Mexico', 'Venezuela (Bolivarian Republic of)']
Asia = ['China','India','Philippines','Vietnam']
Middle_East = ['Afghanistan', 'Iraq', 'Pakistan', 'Syria']
Africa = ['Ethiopia', 'Ghana', 'Kenya', 'Nigeria', 'Somalia', 'South Africa']
Central_America + Asia + Middle_East + Africa
# Out:
# ['Cuba',
#  'El Salvador',
#  'Guatemala',
#  'Honduras',
#  'Mexico',
#  'Venezuela (Bolivarian Republic of)',
#  'China',
#  'India',
#  'Philippines',
#  'Vietnam',
#  'Afghanistan',
#  'Iraq',
#  'Pakistan',
#  'Syria',
#  'Ethiopia',
#  'Ghana',
#  'Kenya',
#  'Nigeria',
#  'Somalia',
#  'South Africa']

# %%
central_origin =  mf.select_region(male_migrants, Central_America, origin=True)
central_destination = mf.select_region(male_migrants, Central_America, origin=False)

# %% [markdown]
# Get the top 3 countries, destination and origin, for Cuba.
#
# This function supports:
#
#     1) country selection
#     2) selection of how many of the top origin/destination countries to display
#     3) Whether were looking at in-migration or out-migration from the selected country
#     4) The year to be looked at

# %%
central_origin_three = mf.get_top_i(central_origin,'Cuba',1990,origin=True,i=5)
central_destination_three = mf.get_top_i(central_destination,'Cuba',1990,origin=False,i=5)
display(central_origin_three.head())
display(central_destination_three.head())
# Out:
#      Year     Code              Country of Destination  \
# 241  1990  1990242            United States of America
# 172  1990  1990173                               Spain
# 204  1990  1990205                         Puerto Rico
# 235  1990  1990236  Venezuela (Bolivarian Republic of)
# 197  1990  1990198                  Dominican Republic
#
#      Country of Origin: Cuba (Counts)
# 241                            736971
# 172                             21854
# 204                             19579
# 235                             11559
# 197                              6824
#      Year     Code         Country of Origin  \
# 193  1990  1990195                     Spain
# 170  1990  1990195        Russian Federation
# 92   1990  1990195                     Haiti
# 216  1990  1990195                   Ukraine
# 220  1990  1990195  United States of America
#
#      Country of Destination: Cuba (Counts)
# 193                                  10703
# 170                                   4491
# 92                                    2063
# 216                                   1367
# 220                                   1186

# %%
# pivots above format into one row
def table_to_row(table, country, origin=True):
    year = table.iloc[0,0]
    code = table.iloc[0,1]
    
    if origin:
        dest_countries = table['Country of Destination']
        counts = table['Country of Origin: '+ country + ' (Counts)']
        
        keys = ['Year', 'Country', 'Code', 'Origin'] + list(dest_countries)
        values = [[i] for i in  [year, country, code, 1] + list(counts)]
        
        dictionary = dict(zip(keys, values))
        
    else:
        origin_countries = table['Country of Origin']
        counts = table['Country of Destination: '+ country + ' (Counts)']
        
        
        keys = ['Year', 'Country', 'Code', 'Origin'] + list(origin_countries)
        values =  [[i] for i in [year, country, code, 0] + list(counts)]
        
    
    return pd.DataFrame(dict(zip(keys, values)))

# %%
table_to_row(central_destination_three, 'Cuba', origin=False)
# Out:
#    Year Country     Code  Origin  Spain  Russian Federation  Haiti  Ukraine  \
# 0  1990    Cuba  1990195       0  10703                4491   2063     1367
#
#    United States of America
# 0                      1186

# %%
table_to_row(central_origin_three, 'Cuba', origin=True)
# Out:
#    Year Country     Code  Origin  United States of America  Spain  \
# 0  1990    Cuba  1990242       1                    736971  21854
#
#    Puerto Rico  Venezuela (Bolivarian Republic of)  Dominican Republic
# 0        19579                               11559                6824

# %%
male_migrants
# Out:
#       Year     Code                             Country     Total  \
# 13    1990  1990014                             Burundi    333110
# 14    1990  1990015                             Comoros     14079
# 15    1990  1990016                            Djibouti    122221
# 16    1990  1990017                             Eritrea     11848
# 17    1990  1990018                            Ethiopia   1155390
# 18    1990  1990019                               Kenya    297292
# 19    1990  1990020                          Madagascar     23917
# 20    1990  1990021                              Malawi   1127724
# 21    1990  1990022                           Mauritius      3613
# 22    1990  1990023                             Mayotte     15229
# 23    1990  1990024                          Mozambique    122332
# 24    1990  1990025                             Réunion     57210
# 25    1990  1990026                              Rwanda    159869
# 26    1990  1990027                          Seychelles      3721
# 27    1990  1990028                             Somalia    478294
# 28    1990  1990029                         South Sudan         0
# 29    1990  1990030                              Uganda    558307
# 30    1990  1990031         United Republic of Tanzania    574025
# 31    1990  1990032                              Zambia    279029
# 32    1990  1990033                            Zimbabwe    626821
# 34    1990  1990035                              Angola     33517
# 35    1990  1990036                            Cameroon    265344
# 36    1990  1990037            Central African Republic     67234
# 37    1990  1990038                                Chad     74342
# 38    1990  1990039                               Congo    129597
# 39    1990  1990040    Democratic Republic of the Congo    754194
# 40    1990  1990041                   Equatorial Guinea      2740
# 41    1990  1990042                               Gabon    127980
# 42    1990  1990043               Sao Tome and Principe      5582
# 44    1990  1990045                             Algeria    273954
# ...    ...      ...                                 ...       ...
# 1854  2017  2017235                             Uruguay     79586
# 1855  2017  2017236  Venezuela (Bolivarian Republic of)   1426336
# 1857  2017  2017238                             Bermuda     18954
# 1858  2017  2017239                              Canada   7861226
# 1859  2017  2017240                           Greenland      6014
# 1860  2017  2017241           Saint Pierre and Miquelon       990
# 1861  2017  2017242            United States of America  49776970
# 1864  2017  2017245                           Australia   7035560
# 1865  2017  2017246                         New Zealand   1067423
# 1867  2017  2017248                                Fiji     13911
# 1868  2017  2017249                       New Caledonia     66001
# 1869  2017  2017250                    Papua New Guinea     32389
# 13                 0      0       0         0
# 14                 0      0       0         0
# 15                 0    289       0         0
# 16                 0      0      91        82
# 17                 0     68       0         0
# 18                 0      0       0         0
# 19                 0      0       0         0
# 20                 0      0    5637      3851
# 21                 0      0       0         0
# 22                 0      0       0         0
# 23                 0      0    1288      8455
# 24                 0      0       0         0
# 25                 0      0       0         0
# 26                 0      0       0         0
# 27                 0      0       0         0
# 28                 0      0       0         0
# 29                 0      0       0         0
# 30                 0      0   18188       488
# 31                 0      0       0     34625
# 32                 0      0   17966         0
# 34                 0      0     119         0
# 35                 0      0       0         0
# 36                 0      0       0         0
# 37                 0      0       0         0
# 38                 0      0       0         0
# 39                 0      0       0         0
# 40                 0      0       0         0
# 41                 0      0       0         0
# 42                 0      0       0         0
# 44            167905   2593       0         0
# ...              ...    ...     ...       ...
# 1854               0      0       0         0
# 1855               0      0       0        15
# 1857               0      0       0         0
# 1858               0   1976    3742     10532
# 1859               0      0       0         0
# 1860               0      0       0         0
# 1861               0  44905   24455     54567
# 1864               0    707    7465     40724
# 1865               0      0    1510      8640
# 1867               0      0       0         0
# 1868               0      0       0         0
# 1869               0      0       0         0
# 1870               0      0       0         0
# 1871               0      0       0         0
# 1873               0      0       0         0
# 1874               0      0       0         0
# 1875               0      0       0         0
# 1876               0      0       0         0
# 1877               0      0       0         0
# 1878               0      0       0         0
# 1879               0      0       0         0
# 1881               0      0       0         0
# 1882               0      0       0         0
# 1883               0      0       0         0
# 1884               0      0       0         0
# 1885               0      0       0         0
# 1886               0      0       0         0
# 1887               0      0       0         0
# 1888               0      0       0         0
# 1889               0      0       0         0
#
# [1624 rows x 236 columns]

# %%
mf.master(male_migrants)
# Out:
# /Users/jordanjomsky/Desktop/IAS-150/migrant_functions.py:97: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   temp = pd.concat([table1, table2])
# /Users/jordanjomsky/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-f769e603a961> in <module>
# ----> 1 mf.master(male_migrants)
#
# ~/Desktop/IAS-150/migrant_functions.py in master(table)
#     114     temp = pd.DataFrame()
#     115     for country in master_list:
# --> 116         table = country_table(table, country)
#     117         temp = concatenate(temp, table)
#     118     return temp
#
# ~/Desktop/IAS-150/migrant_functions.py in country_table(table, country)
#     103     for year in table["Year"].unique():
#     104         origin = get_top_i(table, country, year, origin=True, i=5)
# --> 105         destination = get_top_i(table, country, year, origin=False, i=5)
#     106         origin = table_to_row(origin, country, origin=True)
#     107         destination = table_to_row(destination, country, origin=False)
#
# ~/Desktop/IAS-150/migrant_functions.py in get_top_i(table, country, year, origin, i)
#      63         table = table.loc[table['Year'] == year, :]
#      64         table = table.loc[table['Country'] == country,:]
# ---> 65         table = columns_to_rows(table)
#      66         table = table.sort_values(by=['Country of Destination: ' + country + ' (Counts)'], ascending=False)[0:i]
#      67     return table
#
# ~/Desktop/IAS-150/migrant_functions.py in columns_to_rows(table)
#      40 def columns_to_rows(table):
#      41
# ---> 42     country_original = table['Country'].iloc[0]
#      43     country_list = list(table)[4:]
#      44     year = table.iloc[0,0]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2100
#    2101             # validate the location
# -> 2102             self._validate_integer(key, axis)
#    2103
#    2104             return self._get_loc(key, axis=axis)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds
